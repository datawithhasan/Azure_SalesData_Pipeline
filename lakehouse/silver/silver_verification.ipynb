# %% [markdown]
# # 1. sales_orders

# %%
# %sql
SELECT * FROM azuresalesdatabricks.silver.sales_orders ORDER BY order_date LIMIT 20;

# %%
# %sql
SELECT COUNT(*) AS bronze_total_rows FROM azuresalesdatabricks.bronze.sales_orders;
SELECT COUNT(*) AS silver_total_rows FROM azuresalesdatabricks.silver.sales_orders;

# %%
# %sql
SELECT DISTINCT order_status FROM azuresalesdatabricks.silver.sales_orders ORDER BY order_status;

# %%
# %sql
SELECT COUNT(*) AS null_dates FROM azuresalesdatabricks.silver.sales_orders WHERE order_date IS NULL;

# %% [markdown]
# ## 2. order_items

# %%
# %sql
SELECT COUNT(*) FROM azuresalesdatabricks.silver.order_items;

# %%
# %sql
SELECT * FROM azuresalesdatabricks.silver.order_items;

# %% [markdown]
# # 3. order_items_quarantine

# %%
# %sql
SELECT _quarantine_reason, COUNT(*) FROM azuresalesdatabricks.silver.order_items_quarantine GROUP BY _quarantine_reason;

# %% [markdown]
# # 4. returns

# %%
# %sql
SELECT COUNT(*) FROM azuresalesdatabricks.silver.returns;

# %%
# %sql
SELECT * FROM azuresalesdatabricks.silver.returns ORDER BY return_date LIMIT 10;

# %% [markdown]
# # 5. customers

# %%
# %sql
SELECT COUNT(*) FROM azuresalesdatabricks.silver.customers;

# %%
# %sql
SELECT * FROM azuresalesdatabricks.silver.customers WHERE customer_id IN
  (SELECT customer_id FROM azuresalesdatabricks.silver.customers GROUP BY customer_id HAVING COUNT(*) > 1)
  ORDER BY customer_id, effective_start_date;

# %% [markdown]
# # 6. products, stores and sales_reps

# %%
# %sql
SELECT COUNT(*) FROM azuresalesdatabricks.silver.products;

# %%
# %sql
SELECT COUNT(*) FROM azuresalesdatabricks.silver.stores;

# %%
# %sql
SELECT COUNT(*) FROM azuresalesdatabricks.silver.sales_reps;

# %%
for e in entities_scd2:
    total = spark.table(e["target_table"]).count()
    current = spark.table(e["target_table"]).filter("is_current = true").count()
    print(f"{e['entity_name']}: {total} total rows, {current} current rows")

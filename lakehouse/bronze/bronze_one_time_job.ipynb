# %% [markdown]
# # Testing purpose

# %%
file_path = "abfss://raw@azuresales.dfs.core.windows.net/dimensions/customers/customers.csv"

# Read directly from new secure location without any configuration lines!
df = spark.read.format("csv").option("header", "true").load(file_path)

display(df)

# %% [markdown]
# # 1. Create the bronze schema and managed location in Unity Catalog

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS azuresalesdatabricks.bronze
MANAGED LOCATION 'abfss://bronze@azuresales.dfs.core.windows.net/';

# %% [markdown]
# # 2. Adding new column in customers

# %%
# %sql
ALTER TABLE azuresalesdatabricks.bronze.customers ADD COLUMN _entity STRING;

# %%
# %sql
DESCRIBE TABLE azuresalesdatabricks.bronze.customers;

# %%
# %sql
DESCRIBE TABLE azuresalesdatabricks.bronze.products;

# %%
# %sql
DESCRIBE TABLE azuresalesdatabricks.bronze.stores;

# %%
# %sql
DESCRIBE TABLE azuresalesdatabricks.bronze.sales_reps;

# %%
# %sql
DESCRIBE TABLE azuresalesdatabricks.bronze.sales_orders;

# %%
# %sql
DESCRIBE TABLE azuresalesdatabricks.bronze.order_items;

# %%
# %sql
DESCRIBE TABLE azuresalesdatabricks.bronze.returns;
